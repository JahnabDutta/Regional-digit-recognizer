# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

# %%
file1 = "E:/ED project/2 test.jpg"
image1 = imread(file1)
plt.imshow(image1)
plt.show()

# %%
file2 = "E:/ED project/bengali/4 test.JPG"
image2 = imread(file2)
plt.imshow(image2)
plt.show()
plt.close()

# %%
digit_1 = "E:/ED project/1 (64).jpg"
digit_2 = "E:/ED project/2(17).jpg"
digit_3 = "E:/ED project/3 0.jpg"
digit_4 = "E:/ED project/4 (26).jpg"

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
from matplotlib import pyplot
from matplotlib.image import imread


def load_image(filename):
        
        img = load_img(filename, target_size=(100, 100))
        
        img = img_to_array(img)
        
        img = img.reshape(1, 100, 100, 3)
        
        img = img.astype('float32')
        return img


def run_example():
    
    img = load_image(file1)
 
    model = load_model('final_model_bengali(2).h5')
    
    
   
    result = list(model.predict(img)[0])
    
    #Present result
    image = imread(file1)
    plt.imshow(image)
    plt.title("The actual digit image")
    plt.show()
    num = result.index(max(result))
    if num == 0:
        print("Predicted : 1")
    elif num == 1:
        print("Predicted : 2")
    elif num == 2:
        print("Predicted : 3")
    elif num == 3:
        print("Predicted : 4")
run_example()
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002040461AB80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Predicted : 2
